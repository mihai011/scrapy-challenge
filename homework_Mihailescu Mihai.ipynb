# %%
#import modules
from lxml import html
import re
import requests
import pandas as pd
from datetime import datetime

#get html and tree
html_page_link = 'candidateEvalData/webpage.html'
with open(html_page_link) as f:
    html_content = f.read()
utf8_parser = html.HTMLParser(encoding='utf-8')
html_tree = html.document_fromstring(html_content , parser=utf8_parser)

data = {}
# parse artist name
artist_name = html_tree.xpath("//h1[@class='lotName']")[0]
data["Artist name"] = artist_name.text.split(" (")[0]

# parse painting name
painting_name = html_tree.xpath("//h2[@class='itemName']/i")[0]
data["Painting name"] = painting_name.text

# parse price GBP
price_GBP = html_tree.xpath("//span[@id='main_center_0_lblPriceRealizedPrimary']")[0]
data["Price GBP"] = int(re.sub(r'(,)|([A-Z])*', "", price_GBP.text))

# parse price US
price_US = html_tree.xpath("//div[@id='main_center_0_lblPriceRealizedSecondary']")[0]
data["Price USD"] = int(re.sub(r'(,)|([A-Z])*', "", price_US.text))

# parse price GBP est
price_GBP_est = html_tree.xpath("//span[@id='main_center_0_lblPriceEstimatedPrimary']")[0]
price_GBP_sub = re.sub(r'(,)|([A-Z])*|(\s)', "", price_GBP_est.text)
est_GBP_split = price_GBP_sub.split("-")
data["Price GBP est"] = [(int(est_GBP_split[0]),int(est_GBP_split[1]))]

# parse price US est
price_US_est = html_tree.xpath("//span[@id='main_center_0_lblPriceEstimatedSecondary']")[0]
price_US_sub = re.sub(r'(,)|([A-Z])*|(\s)|[()]', "", price_US_est.text)
est_US_split = price_US_sub.split("-")
data["Price US est"] = [(int(est_US_split[0]),int(est_US_split[1]))]

# image link
image_link = html_tree.xpath("//img[@id='imgLotImage']")[0]
data["Image link"] = image_link.attrib['src']

df = pd.DataFrame(data=data)
df.head()
# Out:
#   Artist name                        Painting name  Price GBP  Price USD  \
# 0  Peter Doig  The Architect's Home in the Ravine    11282500   16370908
#
#           Price GBP est          Price US est  \
# 0  (10000000, 15000000)  (14509999, 21764999)
#
#                                           Image link
# 0  http://www.christies.com/lotfinderimages/D5973...

# %%
import pandas as pd
dim_df = pd.read_csv("candidateEvalData/dim_df_correct.csv")
import pandas as pd
import re
dim_df = pd.read_csv("candidateEvalData/dim_df_correct.csv")
regular_expressions = [r"(\d+(\.|,)+\d*)",r"(\d+(\.|,)*\d*)"]
# used two regular expression for collecting centimeters  dimensions
for row in dim_df["rawDim"]:
    
    for r in regular_expressions:
        matches = re.findall(r,row)
        if len(matches)  >= 2:
            print(row, " ".join(m[0] for m in matches))
            break
# Out:
# 19×52cm 19 52
# 50 x 66,4 cm 50 66,4
# 168.9 x 274.3 x 3.8 cm (66 1/2 x 108 x 1 1/2 in.) 168.9 274.3 3.8
# Sheet: 16 1/4 × 12 1/4 in. (41.3 × 31.1 cm) Image: 14 × 9 7/8 in. (35.6 × 25.1 cm) 41.3 31.1 35.6 25.1
# 5 by 5in 5 5

# %%
import scrapy
import pandas as pd
from scrapy import Item, Field
import re
from scrapy.crawler import CrawlerProcess


# for simplicity and performance, I iterate over the content
# of this page that contains all the artwork pieces
# as an alternative we could iterate over each page, but since 
# we can get all art items in a single pace like so, we can do it like this in
# a initial faze
URL = "https://www.bearspace.co.uk/purchase?page=1000"
items = []

class ArtPiece(Item):
    url = Field()
    title = Field()
    media = Field()
    height_cm = Field()
    width_cm = Field()
    price_gbp = Field()

class ArtCrawler(scrapy.Spider):
    name = "artcrawler"
    start_urls = [URL]
    
    def parse(self, response):
        sels = response.xpath("//a[@class='oQUvqL x5qIv3']")
        # for all art pieces in the main page we run 
        # the parsing function for each one
        for s in sels:
            url = s.attrib['href']
            yield scrapy.Request(url, callback = self.parse_item)
            
    def parse_item(self, response):
        art_piece = ArtPiece()
        
        # getting the art title and price in GBP but data-hooks
        art_piece["url"] = response.url
        art_piece["title"] = response.xpath("//h1[@data-hook='product-title']/text()").get()
        art_piece["price_gbp"] = response.xpath("//span[@data-hook='formatted-primary-price']/text()").get()
        # media and dimensions are in the 'description' data-hook container
        contents = response.xpath("//pre[@data-hook='description']//text()").extract()
        dimensions = None
        media = []
        # dimensions are retrieved using a regular expression and the first 
        # matches are captured, the rest are added to the media field
        # since the data in the content does not follow a specific format
        if contents:
            for content in contents:
                check_dim = re.findall(r"(\d+(\.|,)*\d*)", content)
                if check_dim and len(check_dim) >= 2 and not dimensions:
                    dimensions = check_dim
                elif not dimensions:
                    media.append(content)
            if dimensions:
                art_piece["height_cm"] = dimensions[0][0]
                art_piece["width_cm"] = dimensions[1][0]
            art_piece["media"] = " ".join(media)
        items.append(art_piece)
        yield art_piece
        
if __name__ == "__main__":
    
    process = CrawlerProcess()
    process.crawl(ArtCrawler)
    process.start()
    
    print(items)
    
    df = pd.DataFrame(items, columns=['url','title','media','height_cm','width_cm', 'price_gbp'])
    df
# Out:
# 2022-12-18 13:42:14 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: scrapybot)
# 2022-12-18 13:42:14 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.10.2, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.16 (main, Dec  7 2022, 10:06:04) - [Clang 14.0.0 (clang-1400.0.29.202)], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.3, Platform macOS-13.1-arm64-arm-64bit
# 2022-12-18 13:42:14 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2022-12-18 13:42:14 [py.warnings] WARNING: /opt/homebrew/lib/python3.9/site-packages/scrapy/utils/request.py:231: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2022-12-18 13:42:14 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-12-18 13:42:14 [scrapy.extensions.telnet] INFO: Telnet Password: 512fa85bd749eb3b
# 2022-12-18 13:42:14 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2022-12-18 13:42:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-12-18 13:42:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-12-18 13:42:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-12-18 13:42:15 [scrapy.core.engine] INFO: Spider opened
# 2022-12-18 13:42:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-12-18 13:42:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-12-18 13:42:16 [filelock] DEBUG: Attempting to acquire lock 5098989696 on /Users/mika/.cache/python-tldextract/3.9.16.final__3.9__ef9f08__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-18 13:42:16 [filelock] DEBUG: Lock 5098989696 acquired on /Users/mika/.cache/python-tldextract/3.9.16.final__3.9__ef9f08__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-18 13:42:16 [filelock] DEBUG: Attempting to release lock 5098989696 on /Users/mika/.cache/python-tldextract/3.9.16.final__3.9__ef9f08__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-18 13:42:16 [filelock] DEBUG: Lock 5098989696 released on /Users/mika/.cache/python-tldextract/3.9.16.final__3.9__ef9f08__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-12-18 13:42:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/purchase?page=1000> (referer: None)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/you-took-my-breath-away-by-dominic-badnum> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/meld-4-by-vic-wright> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/take-my-hand-by-dominic-badnum> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-tide-seems-to-whisper-your-name-by-dominic-badnum> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/p10-by-olly-fathers> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/disperse-by-dionne-cole> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/i-see-beauty-in-everything-by-dominic-badnum> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/you-took-my-breath-away-by-dominic-badnum>
# {'height_cm': '40',
#  'media': 'oil with charcoal, watercolour and pencil on canvas',
#  'price_gbp': '£640.00',
#  'title': 'This Day Is Ours by Dominic Bradnum',
#  'url': 'https://www.bearspace.co.uk/product-page/you-took-my-breath-away-by-dominic-badnum',
#  'width_cm': '50'}
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/meld-4-by-vic-wright>
# {'height_cm': '18',
#  'media': '13K gold leaf, copper leaf, white casting cement, iron and pigment',
#  'price_gbp': '£440.00',
#  'title': 'Meld 4 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/meld-4-by-vic-wright',
#  'width_cm': '15'}
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/purple-motion-by-dionne-cole> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/take-my-hand-by-dominic-badnum>
# {'height_cm': '40',
#  'media': 'oil on canvas with charcoal and watercolour',
#  'price_gbp': '£840.00',
#  'title': 'Take My Hand by Dominic Badnum',
#  'url': 'https://www.bearspace.co.uk/product-page/take-my-hand-by-dominic-badnum',
#  'width_cm': '50'}
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-tide-seems-to-whisper-your-name-by-dominic-badnum>
# {'height_cm': '80',
#  'media': 'oil on canvas',
#  'price_gbp': '£1,600.00',
#  'title': 'The Tide Seems To Whisper Your Name by Dominic Badnum',
#  'url': 'https://www.bearspace.co.uk/product-page/the-tide-seems-to-whisper-your-name-by-dominic-badnum',
#  'width_cm': '100'}
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/p10-by-olly-fathers>
# {'height_cm': '30',
#  'media': 'Acrylic paint on sprayed board',
#  'price_gbp': '£240.00',
#  'title': 'P10 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/p10-by-olly-fathers',
#  'width_cm': '30'}
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/disperse-by-dionne-cole>
# {'height_cm': '76',
#  'media': '',
#  'price_gbp': '£1,400.00',
#  'title': 'Disperse by Dionne Cole',
#  'url': 'https://www.bearspace.co.uk/product-page/disperse-by-dionne-cole',
#  'width_cm': '101.6'}
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/i-see-beauty-in-everything-by-dominic-badnum>
# {'height_cm': '80',
#  'media': 'oil on canvas with charcoal and watercolour',
#  'price_gbp': '£1,600.00',
#  'title': 'I See Beauty In Everything by Dominic Badnum',
#  'url': 'https://www.bearspace.co.uk/product-page/i-see-beauty-in-everything-by-dominic-badnum',
#  'width_cm': '100'}
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/purple-motion-by-dionne-cole>
# {'height_cm': '59.4',
#  'media': '',
#  'price_gbp': '£1,200.00',
#  'title': 'Purple Motion by Dionne Cole',
#  'url': 'https://www.bearspace.co.uk/product-page/purple-motion-by-dionne-cole',
#  'width_cm': '84.1'}
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/castle-2-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/meld-5-by-vic-wright> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/unfathomable-deeps-by-jane-ward-1> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/castle-2-by-jane-ward>
# {'height_cm': '45',
#  'media': 'Digital print on Aluminium',
#  'price_gbp': '£640.00',
#  'title': 'Castle 2 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/castle-2-by-jane-ward',
#  'width_cm': '60'}
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/meld-5-by-vic-wright>
# {'height_cm': '17',
#  'media': '16K goldleaf, white casting cement, pigment and ink',
#  'price_gbp': '£440.00',
#  'title': 'Meld 6 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/meld-5-by-vic-wright',
#  'width_cm': '18'}
# 2022-12-18 13:42:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-ephemeral-isles-1-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:18 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/unfathomable-deeps-by-jane-ward-1>
# {'height_cm': '24',
#  'media': 'Digital print on Aluminium',
#  'price_gbp': '£340.00',
#  'title': 'Unfathomable Deeps by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/unfathomable-deeps-by-jane-ward-1',
#  'width_cm': '30'}
# 2022-12-18 13:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/from-frozen-floods-by-jane-ward-1> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-ephemeral-isles-1-by-jane-ward>
# {'height_cm': '90',
#  'media': 'Digital print on Aluminium',
#  'price_gbp': '£1,800.00',
#  'title': 'The Ephemeral Isles 1 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/the-ephemeral-isles-1-by-jane-ward',
#  'width_cm': '120'}
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/from-frozen-floods-by-jane-ward-1>
# {'height_cm': '24',
#  'media': 'Digital print on Aluminium',
#  'price_gbp': '£340.00',
#  'title': 'From Frozen Floods by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/from-frozen-floods-by-jane-ward-1',
#  'width_cm': '30'}
# 2022-12-18 13:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-ephemeral-isles-5a-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/those-hidden-ravines-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-ephemeral-isles-5a-by-jane-ward>
# {'height_cm': '45',
#  'media': 'Digital print on canvas with\xa0dissolved ink',
#  'price_gbp': '£490.00',
#  'title': 'The Ephemeral Isles 5 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/the-ephemeral-isles-5a-by-jane-ward',
#  'width_cm': '60'}
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/those-hidden-ravines-by-jane-ward>
# {'height_cm': '45',
#  'media': 'Digital print on Aluminium',
#  'price_gbp': '£640.00',
#  'title': 'Those Hidden Ravines by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/those-hidden-ravines-by-jane-ward',
#  'width_cm': '60'}
# 2022-12-18 13:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/boondocks-by-suzanne-moxhay> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/gloaming-by-suzanne-moxhay> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/boondocks-by-suzanne-moxhay>
# {'height_cm': '92',
#  'media': '',
#  'price_gbp': '£690.00',
#  'title': 'Boondocks by Suzanne Moxhay',
#  'url': 'https://www.bearspace.co.uk/product-page/boondocks-by-suzanne-moxhay',
#  'width_cm': '45'}
# 2022-12-18 13:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/athne-by-suzanne-moxhay> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/gloaming-by-suzanne-moxhay>
# {'height_cm': '60',
#  'media': '',
#  'price_gbp': '£690.00',
#  'title': 'Gloaming by Suzanne Moxhay',
#  'url': 'https://www.bearspace.co.uk/product-page/gloaming-by-suzanne-moxhay',
#  'width_cm': '40'}
# 2022-12-18 13:42:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/feralis-by-suzanne-moxhay> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/athne-by-suzanne-moxhay>
# {'height_cm': '100',
#  'media': '',
#  'price_gbp': '£690.00',
#  'title': 'Athne by Suzanne Moxhay',
#  'url': 'https://www.bearspace.co.uk/product-page/athne-by-suzanne-moxhay',
#  'width_cm': '50'}
# 2022-12-18 13:42:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/feralis-by-suzanne-moxhay>
# {'height_cm': '68',
#  'media': '',
#  'price_gbp': '£690.00',
#  'title': 'Feralis by Suzanne Moxhay',
#  'url': 'https://www.bearspace.co.uk/product-page/feralis-by-suzanne-moxhay',
#  'width_cm': '55'}
# 2022-12-18 13:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/gcs-high-rise-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/bayou> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/gcs-high-rise-jane-ward>
# {'height_cm': '80',
#  'media': 'Digital print with dissolved ink',
#  'price_gbp': '£990.00',
#  'title': '(GCS) High Rise - Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/gcs-high-rise-jane-ward',
#  'width_cm': '60'}
# 2022-12-18 13:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/bayou>
# {'height_cm': '100',
#  'media': '',
#  'price_gbp': '£690.00',
#  'title': 'Bayou',
#  'url': 'https://www.bearspace.co.uk/product-page/bayou',
#  'width_cm': '44'}
# 2022-12-18 13:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-6-by-janie-kidston> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-3-by-janie-kidston> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/walking-out-over-ice-in-midsummer-1> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-6-by-janie-kidston>
# {'height_cm': '50',
#  'media': '',
#  'price_gbp': '£540.00',
#  'title': "'Retreating, then advancing repeatedly over the centuries 6' by "
#           'Janie Kidston',
#  'url': 'https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-6-by-janie-kidston',
#  'width_cm': '60'}
# 2022-12-18 13:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-3-by-janie-kidston>
# {'height_cm': '50',
#  'media': '',
#  'price_gbp': '£540.00',
#  'title': "'Retreating, then advancing repeatedly over the centuries 3' by "
#           'Janie Kidston',
#  'url': 'https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-3-by-janie-kidston',
#  'width_cm': '60'}
# 2022-12-18 13:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/walking-out-over-ice-in-midsummer-1>
# {'height_cm': '84',
#  'media': 'Archival Digital Print',
#  'price_gbp': '£940.00',
#  'title': 'Walking Out Over Ice in Midsummer 1 by Janie Kidston',
#  'url': 'https://www.bearspace.co.uk/product-page/walking-out-over-ice-in-midsummer-1',
#  'width_cm': '59'}
# 2022-12-18 13:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/moving-from-the-side-of-the-vallery> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-5> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/moving-from-the-side-of-the-vallery>
# {'height_cm': '50',
#  'media': '',
#  'price_gbp': '£540.00',
#  'title': 'Moving from the side of the valley by Janie Kidston',
#  'url': 'https://www.bearspace.co.uk/product-page/moving-from-the-side-of-the-vallery',
#  'width_cm': '60'}
# 2022-12-18 13:42:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-5>
# {'height_cm': '50',
#  'media': '',
#  'price_gbp': '£540.00',
#  'title': "'Retreating, then advancing repeatedly over the centuries'5 by "
#           'Janie Kidston',
#  'url': 'https://www.bearspace.co.uk/product-page/retreating-then-advancing-repeatedly-over-the-centuries-5',
#  'width_cm': '60'}
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/castle-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/neon-pool> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/amongst-the-impcat-scars> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/jubellied-joy-song-by-nadja-gabriela-plein> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/castle-by-jane-ward>
# {'height_cm': '90',
#  'media': '',
#  'price_gbp': '£940.00',
#  'title': 'Castle by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/castle-by-jane-ward',
#  'width_cm': '70'}
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/from-steep-to-steep-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/neon-pool>
# {'height_cm': '39',
#  'media': 'Acrylic and oil on board 2016',
#  'price_gbp': '£640.00',
#  'title': 'Lucinda Metcalfe - Neon Pool',
#  'url': 'https://www.bearspace.co.uk/product-page/neon-pool',
#  'width_cm': '49.5'}
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/amongst-the-impcat-scars>
# {'height_cm': '125',
#  'media': '',
#  'price_gbp': '£1,400.00',
#  'title': 'Amongst the Impcat Scars by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/amongst-the-impcat-scars',
#  'width_cm': '90'}
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/jubellied-joy-song-by-nadja-gabriela-plein>
# {'height_cm': '50',
#  'media': '',
#  'price_gbp': '£490.00',
#  'title': 'Jubellied (joy song) by Nadja Gabriela Plein',
#  'url': 'https://www.bearspace.co.uk/product-page/jubellied-joy-song-by-nadja-gabriela-plein',
#  'width_cm': '41'}
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/heated-discussion-by-lucinda-metcalfe> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/from-steep-to-steep-by-jane-ward>
# {'height_cm': '45',
#  'media': 'Digital print on Aluminium',
#  'price_gbp': '£640.00',
#  'title': 'From Steep to Steep by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/from-steep-to-steep-by-jane-ward',
#  'width_cm': '60'}
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/heated-discussion-by-lucinda-metcalfe>
# {'height_cm': '43',
#  'media': '',
#  'price_gbp': '£640.00',
#  'title': 'Heated Discussion by Lucinda Metcalfe',
#  'url': 'https://www.bearspace.co.uk/product-page/heated-discussion-by-lucinda-metcalfe',
#  'width_cm': '38'}
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/secret-place-by-natasha-kissell> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/secret-place-by-natasha-kissell>
# {'height_cm': '70',
#  'media': '',
#  'price_gbp': '£940.00',
#  'title': 'Secret Place by Natasha Kissell',
#  'url': 'https://www.bearspace.co.uk/product-page/secret-place-by-natasha-kissell',
#  'width_cm': '60'}
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/garden-city-state-1a-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/sky-walk-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/then-all-was-calm> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/garden-city-state-1c-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/garden-city-state-1a-by-jane-ward>
# {'height_cm': '60',
#  'media': '',
#  'price_gbp': '£490.00',
#  'title': 'Garden City State 1a by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/garden-city-state-1a-by-jane-ward',
#  'width_cm': '45'}
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/i-crash-into-your-arms> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/garden-city-state-1b-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/sky-walk-by-jane-ward>
# {'height_cm': '90',
#  'media': '',
#  'price_gbp': '£940.00',
#  'title': 'Sky Walk by Jane ward',
#  'url': 'https://www.bearspace.co.uk/product-page/sky-walk-by-jane-ward',
#  'width_cm': '70'}
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/then-all-was-calm>
# {'height_cm': '110',
#  'media': '',
#  'price_gbp': '£2,400.00',
#  'title': 'Then All Was Calm... by Dominic Bradnum',
#  'url': 'https://www.bearspace.co.uk/product-page/then-all-was-calm',
#  'width_cm': '150'}
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/garden-city-state-1c-by-jane-ward>
# {'height_cm': '60',
#  'media': '',
#  'price_gbp': '£490.00',
#  'title': 'Garden City State 1c by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/garden-city-state-1c-by-jane-ward',
#  'width_cm': '45'}
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/under-a-bruised-and-leaden-sky-by-dominic-badnum> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/i-crash-into-your-arms>
# {'height_cm': '70',
#  'media': 'Oil with charcoal, watercolour, salt & sand on canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'I Crash Into Your Arms by Dominic Bradnum',
#  'url': 'https://www.bearspace.co.uk/product-page/i-crash-into-your-arms',
#  'width_cm': '100'}
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/garden-city-state-1b-by-jane-ward>
# {'height_cm': '60',
#  'media': '',
#  'price_gbp': '£490.00',
#  'title': 'Garden City State 1b by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/garden-city-state-1b-by-jane-ward',
#  'width_cm': '45'}
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/anxiety-machines> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/under-a-bruised-and-leaden-sky-by-dominic-badnum>
# {'height_cm': '100',
#  'media': 'Oil with charcoal & watercolour on canvas',
#  'price_gbp': '£1,600.00',
#  'title': 'Under A Bruised And Leaden Sky by Dominic Badnum',
#  'url': 'https://www.bearspace.co.uk/product-page/under-a-bruised-and-leaden-sky-by-dominic-badnum',
#  'width_cm': '100'}
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/anxiety-machines>
# {'height_cm': '99',
#  'media': 'Oil, enamel and acrylic on canvas',
#  'price_gbp': '£1,600.00',
#  'title': 'Anxiety Machines by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/anxiety-machines',
#  'width_cm': '99'}
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/protist-peak-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/seth-s-narrows-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/relic-engines-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/protist-peak-by-chris-hawtin>
# {'height_cm': '40',
#  'media': 'Oil and acrylic on canvas',
#  'price_gbp': '£690.00',
#  'title': 'Protist Peak by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/protist-peak-by-chris-hawtin',
#  'width_cm': '50'}
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/seth-s-narrows-by-chris-hawtin>
# {'height_cm': '59',
#  'media': 'Oil and acrylic on canvas',
#  'price_gbp': '£800.00',
#  'title': "Seth's Narrows by Chris Hawtin",
#  'url': 'https://www.bearspace.co.uk/product-page/seth-s-narrows-by-chris-hawtin',
#  'width_cm': '47'}
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/jerome-s-peak-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/relic-engines-by-chris-hawtin>
# {'height_cm': '45',
#  'media': 'Oil, enamel and acrylic on canvas',
#  'price_gbp': '£690.00',
#  'title': 'Relic Engines by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/relic-engines-by-chris-hawtin',
#  'width_cm': '40'}
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/photeus-at-the-pythia-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/jerome-s-peak-by-chris-hawtin>
# {'height_cm': '132',
#  'media': 'Oil,enamel and acrylic on canvas',
#  'price_gbp': '£2,400.00',
#  'title': "Jerome's Peak by Chris Hawtin",
#  'url': 'https://www.bearspace.co.uk/product-page/jerome-s-peak-by-chris-hawtin',
#  'width_cm': '143'}
# 2022-12-18 13:42:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/gregor-s-hollow-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/photeus-at-the-pythia-by-chris-hawtin>
# {'height_cm': '70',
#  'media': 'Oil and acrylic on canvas',
#  'price_gbp': '£1,200.00',
#  'title': 'Photeus at the Pythia by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/photeus-at-the-pythia-by-chris-hawtin',
#  'width_cm': '70'}
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/gregor-s-hollow-by-chris-hawtin>
# {'height_cm': '198',
#  'media': 'Oil, enamel, acrylic and resin on canvas',
#  'price_gbp': '£4,000.00',
#  'title': "Gregor's Hollow by Chris Hawtin",
#  'url': 'https://www.bearspace.co.uk/product-page/gregor-s-hollow-by-chris-hawtin',
#  'width_cm': '198'}
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-cope-marsh-station> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/tilt-by-chris-hawton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-cope-marsh-station>
# {'height_cm': '86',
#  'media': 'Oil on canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'The Cope Marsh Station by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/the-cope-marsh-station',
#  'width_cm': '86'}
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/tilt-by-chris-hawton>
# {'height_cm': '51',
#  'media': 'Oil and acrylic on canvas',
#  'price_gbp': '£800.00',
#  'title': 'Tilt by Chris Hawton',
#  'url': 'https://www.bearspace.co.uk/product-page/tilt-by-chris-hawton',
#  'width_cm': '46'}
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-vandal-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-dawn-chorus-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-scientist-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-vandal-by-chris-hawtin>
# {'height_cm': '76',
#  'media': 'Screenprint on paper',
#  'price_gbp': '£250.00',
#  'title': 'The Vandal by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/the-vandal-by-chris-hawtin',
#  'width_cm': '56'}
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/myriorama-room-series-armchair-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-dawn-chorus-by-chris-hawtin>
# {'height_cm': '170',
#  'media': '',
#  'price_gbp': '£3,800.00',
#  'title': 'The Dawn Chorus by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/the-dawn-chorus-by-chris-hawtin',
#  'width_cm': '160'}
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-scientist-by-chris-hawtin>
# {'height_cm': '76',
#  'media': 'Screen print on paper',
#  'price_gbp': '£250.00',
#  'title': 'The Scientist by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/the-scientist-by-chris-hawtin',
#  'width_cm': '56'}
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/myriorama-room-series-armchair-by-bella-easton>
# {'height_cm': '89',
#  'media': 'Artist: Bella Easton',
#  'price_gbp': '£2,800.00',
#  'title': 'MYRIORAMA ROOM series –ARMCHAIR by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/myriorama-room-series-armchair-by-bella-easton',
#  'width_cm': '117'}
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/myriorama-room-series-lamp-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/myriorama-room-series-fireplace-ii-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/myriorama-room-series-lamp-by-bella-easton>
# {'height_cm': '89',
#  'media': 'Artist: Bella Easton',
#  'price_gbp': '£2,800.00',
#  'title': 'MYRIORAMA ROOM series - LAMP by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/myriorama-room-series-lamp-by-bella-easton',
#  'width_cm': '117'}
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/myriorama-room-series-fireplace-ii-by-bella-easton>
# {'height_cm': '89',
#  'media': 'Artist: Bella Easton',
#  'price_gbp': '£2,800.00',
#  'title': 'MYRIORAMA ROOM series – FIREPLACE II by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/myriorama-room-series-fireplace-ii-by-bella-easton',
#  'width_cm': '117'}
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/chiral-vi-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-hidden-city-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/chiral-v-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/chiral-vi-by-bella-easton>
# {'height_cm': '40',
#  'media': 'Watercolour and hand coloured copper plate etching on Velin Arches',
#  'price_gbp': '£940.00',
#  'title': 'Chiral VI by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/chiral-vi-by-bella-easton',
#  'width_cm': '18'}
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-hidden-city-by-chris-hawtin>
# {'height_cm': '87',
#  'media': 'Oil and enamel on canvas',
#  'price_gbp': '£1,600.00',
#  'title': 'The Hidden City by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/the-hidden-city-by-chris-hawtin',
#  'width_cm': '101'}
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/chiral-iii-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/chiral-v-by-bella-easton>
# {'height_cm': '40',
#  'media': 'Watercolour and hand coloured copper plate etching on Velin Arches',
#  'price_gbp': '£940.00',
#  'title': 'Chiral V by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/chiral-v-by-bella-easton',
#  'width_cm': '18'}
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/march-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/chiral-iii-by-bella-easton>
# {'height_cm': '40',
#  'media': 'Watercolour and hand coloured copper plate etching on Velin Arches',
#  'price_gbp': '£940.00',
#  'title': 'Chiral III by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/chiral-iii-by-bella-easton',
#  'width_cm': '18'}
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/march-by-chris-hawtin>
# {'height_cm': '57',
#  'media': 'Oil on Canvas',
#  'price_gbp': '£940.00',
#  'title': 'March by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/march-by-chris-hawtin',
#  'width_cm': '62'}
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/chiral-iv-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/chiral-ii-by-bella-easton> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/chiral-iv-by-bella-easton>
# {'height_cm': '40',
#  'media': 'Watercolour and hand coloured copper plate etching on Velin Arches',
#  'price_gbp': '£940.00',
#  'title': 'Chiral IV by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/chiral-iv-by-bella-easton',
#  'width_cm': '18'}
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/chiral-ii-by-bella-easton>
# {'height_cm': '40',
#  'media': 'Watercolour and hand coloured copper plate etching on Velin Arches',
#  'price_gbp': '£940.00',
#  'title': 'Chiral II by Bella Easton',
#  'url': 'https://www.bearspace.co.uk/product-page/chiral-ii-by-bella-easton',
#  'width_cm': '18'}
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/overland-1-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/overland-3-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/alpine-1-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/overland-1-by-jane-ward>
# {'height_cm': '90',
#  'media': 'Archival digital print on canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'Overland 1 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/overland-1-by-jane-ward',
#  'width_cm': '120'}
# 2022-12-18 13:42:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/overland-3-by-jane-ward>
# {'height_cm': '90',
#  'media': 'Archival digital print on canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'Overland 3 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/overland-3-by-jane-ward',
#  'width_cm': '120'}
# 2022-12-18 13:42:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/overland-2-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/alpine-1-by-jane-ward>
# {'height_cm': '40',
#  'media': 'Digital print on canvas with hand dissolved ink',
#  'price_gbp': '£290.00',
#  'title': 'Alpine 1 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/alpine-1-by-jane-ward',
#  'width_cm': '30'}
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/overland-2-by-jane-ward>
# {'height_cm': '90',
#  'media': 'Archival digital print on canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'Overland 2 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/overland-2-by-jane-ward',
#  'width_cm': '120'}
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/overland-4-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/alpine-3-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/overland-4-by-jane-ward>
# {'height_cm': '90',
#  'media': 'Archival digital print on canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'Overland 4 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/overland-4-by-jane-ward',
#  'width_cm': '120'}
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/alpine-3-by-jane-ward-1> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/alpine-3-by-jane-ward>
# {'height_cm': '40',
#  'media': 'Digital print on canvas with hand dissolved ink',
#  'price_gbp': '£290.00',
#  'title': 'Alpine 4 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/alpine-3-by-jane-ward',
#  'width_cm': '30'}
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/alpine-3-by-jane-ward-1>
# {'height_cm': '40',
#  'media': 'Digital print on canvas with hand dissolved ink',
#  'price_gbp': '£290.00',
#  'title': 'Alpine 3 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/alpine-3-by-jane-ward-1',
#  'width_cm': '30'}
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/yeti-over-mount-fuji-pantone-yellow-by-phil-ashcroft> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/summer-breeze-by-lucinda-metcalfe> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/yeti-over-mount-fuji-pantone-yellow-by-phil-ashcroft>
# {'height_cm': '59.4',
#  'media': 'screenprint on paper',
#  'price_gbp': '£150.00',
#  'title': 'YETI OVER MOUNT FUJI (PANTONE YELLOW) by Phil Ashcroft',
#  'url': 'https://www.bearspace.co.uk/product-page/yeti-over-mount-fuji-pantone-yellow-by-phil-ashcroft',
#  'width_cm': '42'}
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/ennio-fallen-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/summer-breeze-by-lucinda-metcalfe>
# {'height_cm': '57.5',
#  'media': '',
#  'price_gbp': '£690.00',
#  'title': 'Summer Breeze by Lucinda Metcalfe',
#  'url': 'https://www.bearspace.co.uk/product-page/summer-breeze-by-lucinda-metcalfe',
#  'width_cm': '45'}
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/venn-s-bluff-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/ennio-fallen-by-chris-hawtin>
# {'height_cm': '198',
#  'media': 'Oil, enamel, acrylic and plaster on canvas',
#  'price_gbp': '£4,000.00',
#  'title': 'Ennio Fallen by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/ennio-fallen-by-chris-hawtin',
#  'width_cm': '198'}
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/venn-s-bluff-by-chris-hawtin>
# {'height_cm': '180',
#  'media': 'Oil, enamel, acrylic and plaster on canvas',
#  'price_gbp': '£3,800.00',
#  'title': "Venn's Bluff by Chris Hawtin",
#  'url': 'https://www.bearspace.co.uk/product-page/venn-s-bluff-by-chris-hawtin',
#  'width_cm': '180'}
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/the-wheel-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/take-our-time-someday-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/alpine-2-by-jane-ward> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/the-wheel-by-chris-hawtin>
# {'height_cm': '198',
#  'media': 'Oil, enamel, acrylic and plaster on canvas',
#  'price_gbp': '£4,000.00',
#  'title': 'The Wheel by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/the-wheel-by-chris-hawtin',
#  'width_cm': '198'}
# 2022-12-18 13:42:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/take-our-time-someday-by-chris-hawtin>
# {'height_cm': '40',
#  'media': 'Oil and acrylic on canvas',
#  'price_gbp': '£640.00',
#  'title': 'Take Our Time (Someday) by Chris Hawtin',
#  'url': 'https://www.bearspace.co.uk/product-page/take-our-time-someday-by-chris-hawtin',
#  'width_cm': '30'}
# 2022-12-18 13:42:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.bearspace.co.uk/product-page/alpine-2-by-jane-ward>
# {'height_cm': '40',
#  'media': 'Digital print on canvas with hand dissolved ink',
#  'price_gbp': '£290.00',
#  'title': 'Alpine 2 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/alpine-2-by-jane-ward',
#  'width_cm': '30'}
# 2022-12-18 13:42:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/loneliness-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# 2022-12-18 13:42:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.bearspace.co.uk/product-page/guiding-light-by-chris-hawtin> (referer: https://www.bearspace.co.uk/purchase?page=1000)
# ...
#  'title': 'Ore by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/ore-by-vic-wright',
#  'width_cm': '8'}, {'height_cm': '16.5',
#  'media': '18K gold leaf and white casting cement',
#  'price_gbp': '£440.00',
#  'title': 'Conversation by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/conversation-by-vic-wright',
#  'width_cm': '13'}, {'height_cm': '12',
#  'media': 'Black and white casting cement with 24k gold leaf',
#  'price_gbp': '£320.00',
#  'title': 'Conversation 2 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/conversation-2-by-vic-wright',
#  'width_cm': '8'}, {'height_cm': '7',
#  'media': '24k gold leaf, white casting cement and ink',
#  'price_gbp': '£140.00',
#  'title': 'Facet 2 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/facet-2-by-vic-wright',
#  'width_cm': '7'}, {'height_cm': '7.5',
#  'media': 'Fine white casting cement and 24k gold leaf',
#  'price_gbp': '£140.00',
#  'title': 'Facet 4 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/facet-4-by-vic-wright',
#  'width_cm': '6'}, {'height_cm': '58',
#  'media': '',
#  'price_gbp': '£1,200.00',
#  'title': 'Green Sanctuary by Dionne Cole',
#  'url': 'https://www.bearspace.co.uk/product-page/green-sanctuary-by-dionne-cole',
#  'width_cm': '85.5'}, {'height_cm': '12',
#  'media': 'Fine white casting cement, ink, crystals and 24k gold leaf',
#  'price_gbp': '£340.00',
#  'title': 'Conversation 3 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/conversation-3-by-vic-wright',
#  'width_cm': '10'}, {'height_cm': '7',
#  'media': 'Fine white casting cement, ink and 18k gold',
#  'price_gbp': '£140.00',
#  'title': 'Facet 3 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/facet-3-by-vic-wright',
#  'width_cm': '7'}, {'media': 'Digital print under\xa0acrylic with subframe 30cm \xa0diam\xa0 '
#           'Edition of 10\xa0 \xa0',
#  'price_gbp': '£320.00',
#  'title': 'Portal 1 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/portal-1-by-jane-ward'}, {'height_cm': '17',
#  'media': '13K gold leaf, copper leaf, white casting cement, iron and pigment',
#  'price_gbp': '£420.00',
#  'title': 'Meld 5',
#  'url': 'https://www.bearspace.co.uk/product-page/copy-of-meld-5',
#  'width_cm': '15'}, {'height_cm': '92',
#  'media': 'Sculpted hand and laser cut paper',
#  'price_gbp': '£2,800.00',
#  'title': 'Flight by Dionne Cole',
#  'url': 'https://www.bearspace.co.uk/product-page/flight-by-dionne-cole',
#  'width_cm': '155'}, {'height_cm': '30.5',
#  'media': '',
#  'price_gbp': '£490.00',
#  'title': 'Shades of Coral II by Dionne Cole',
#  'url': 'https://www.bearspace.co.uk/product-page/shades-of-coral-ii-by-dionne-cole',
#  'width_cm': '40.7'}, {'height_cm': '70',
#  'media': 'Resin, pigments, indian ink, watercolour paper, inkjet prints, MDF',
#  'price_gbp': '£1,200.00',
#  'title': 'FRAGMENTATION No.46 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragmentation-no-46-by-jim-cheatle',
#  'width_cm': '54.5'}, {'height_cm': '8',
#  'media': 'Fine white casting cement, ink and 24k gold leaf',
#  'price_gbp': '£140.00',
#  'title': 'Facet 5 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/facet-5-by-vic-wright',
#  'width_cm': '6.5'}, {'height_cm': '17',
#  'media': '24k gold leaf, white casting cement and ground iron',
#  'price_gbp': '£440.00',
#  'title': 'Meld 1 by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/meld-1-by-vic-wright',
#  'width_cm': '14'}, {'height_cm': '70',
#  'media': 'Resin, pigments, inkjet prints, canvas, MDF',
#  'price_gbp': '£1,200.00',
#  'title': 'FRAGMENTATION No.44 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragmentation-no-44-by-jim-cheatle',
#  'width_cm': '54.5'}, {'height_cm': '70',
#  'media': 'Resin, pigments, inkjet prints, acrylic, paper, MDF',
#  'price_gbp': '£1,200.00',
#  'title': 'FRAGMENTATION No.45 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragmentation-no-45-by-jim-cheatle',
#  'width_cm': '54.5'}, {'height_cm': '30.5',
#  'media': 'Resin, pigments, inkjet prints, MDF',
#  'price_gbp': '£490.00',
#  'title': 'Fragstudy 1 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragstudy-1-by-jim-cheatle',
#  'width_cm': '23'}, {'height_cm': '70',
#  'media': 'Resin, pigments, canvas, paper, inkjet prints, MDF',
#  'price_gbp': '£1,200.00',
#  'title': 'FRAGMENTATION No.17 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragmentation-no-17-by-jim-cheatle',
#  'width_cm': '54.5'}, {'height_cm': '30.5',
#  'media': 'Resin, pigments, inkjet prints, MDF',
#  'price_gbp': '£490.00',
#  'title': 'Fragstudy 3 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragstudy-3-by-jim-cheatle',
#  'width_cm': '23'}, {'height_cm': '70',
#  'media': 'Resin, pigments, paper, indian ink, inkjet prints, MDF',
#  'price_gbp': '£1,200.00',
#  'title': 'FRAGMENTATION No.10 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragmentation-no-10-by-jim-cheatle',
#  'width_cm': '54.5'}, {'height_cm': '70',
#  'media': 'Resin, pigments, canvas, paper, inkjet prints, MDF',
#  'price_gbp': '£1,200.00',
#  'title': 'FRAGMENTATION No.33 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragmentation-no-33-by-jim-cheatle',
#  'width_cm': '54.5'}, {'height_cm': '30.5',
#  'media': 'Resin, pigments, inkjet prints, MDF',
#  'price_gbp': '£490.00',
#  'title': 'Fragstudy 4 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragstudy-4-by-jim-cheatle',
#  'width_cm': '23'}, {'height_cm': '30.5',
#  'media': 'Resin, pigments, inkjet prints, MDF',
#  'price_gbp': '£490.00',
#  'title': 'Fragstudy 2 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragstudy-2-by-jim-cheatle',
#  'width_cm': '23'}, {'media': 'Digital print under\xa0acrylic with subframe 30cm \xa0diam\xa0 '
#           'Edition of 10\xa0 \xa0',
#  'price_gbp': '£320.00',
#  'title': 'Portal 5 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/portal-5-by-jane-ward'}, {'media': 'Digital print under\xa0acrylic with subframe 60cm \xa0diam\xa0 '
#           'Edition of 10\xa0 \xa0',
#  'price_gbp': '£490.00',
#  'title': 'Portal 7 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/portal-7-by-jane-ward'}, {'media': 'Digital print under\xa0acrylic with subframe 60cm \xa0diam\xa0 '
#           'Edition of 10\xa0 \xa0',
#  'price_gbp': '£490.00',
#  'title': 'Portal 8 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/portal-8-by-jane-ward'}, {'height_cm': '30.5',
#  'media': 'Resin, pigments, inkjet prints, MDF',
#  'price_gbp': '£490.00',
#  'title': 'Fragstudy 7 by Jim Cheatle',
#  'url': 'https://www.bearspace.co.uk/product-page/fragstudy-5-by-jim-cheatle',
#  'width_cm': '23'}, {'media': 'Digital print under\xa0acrylic with subframe 60cm \xa0diam\xa0 '
#           'Edition of 10\xa0 \xa0',
#  'price_gbp': '£490.00',
#  'title': 'Portal 9 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/portal-9-by-jane-ward'}, {'media': 'Digital print under\xa0acrylic with subframe 30cm \xa0diam\xa0 '
#           'Edition of 10\xa0 \xa0',
#  'price_gbp': '£320.00',
#  'title': 'Portal 6 by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/portal-6-by-jane-ward'}, {'height_cm': '100',
#  'media': 'Oil with charcoal, watercolour and sand on canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'As The Tide Turned by Dominic Bradnum',
#  'url': 'https://www.bearspace.co.uk/product-page/as-the-tide-turned-by-dominic-bradnum',
#  'width_cm': '80'}, {'height_cm': '40',
#  'media': 'oil on canvas with charcoal, watercolour and pencil',
#  'price_gbp': '£640.00',
#  'title': 'You Took My Breath Away by Dominic Bradnum',
#  'url': 'https://www.bearspace.co.uk/product-page/you-took-my-breath-away-by-dominic-bradnum',
#  'width_cm': '50'}, {'height_cm': '40.7',
#  'media': 'Inkjet Print (Hahnemuhle Ultra-Smooth)',
#  'price_gbp': '£400.00',
#  'title': 'Balancing Acts IV by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/balancing-acts-iv-by-elise-wootten',
#  'width_cm': '50.8'}, {'height_cm': '40.7',
#  'media': 'Inkjet Print (Hahnemuhle Ultra-Smooth)',
#  'price_gbp': '£400.00',
#  'title': 'Balancing Acts II by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/balancing-acts-ii-by-elise-wootten',
#  'width_cm': '50.8'}, {'height_cm': '40.7',
#  'media': 'Inkjet Print (Hahnemuhle Ultra-Smooth)',
#  'price_gbp': '£400.00',
#  'title': 'Balancing Acts I by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/balancing-acts-i-by-elise-wootten',
#  'width_cm': '50.8'}, {'height_cm': '74',
#  'media': 'Aluminium, Inkjet Vinyl Print',
#  'price_gbp': '£640.00',
#  'title': 'Somewhat Confusing I by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/somewhat-confusing-i-by-elise-wootten',
#  'width_cm': '88'}, {'height_cm': '40.9',
#  'media': 'Set of four Beech, Mdf, Acrylic paint, Vinyl',
#  'price_gbp': '£1,200.00',
#  'title': 'All Recognisable Entities by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/all-recognisable-entities-by-elise-wootten',
#  'width_cm': '50.2'}, {'height_cm': '40.7',
#  'media': 'Inkjet Print (Hahnemuhle Ultra-Smooth)',
#  'price_gbp': '£400.00',
#  'title': 'Balancing Acts III by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/balancing-acts-iii-by-elise-wootten',
#  'width_cm': '50.8'}, {'height_cm': '90',
#  'media': 'Archival digital print on canvas with dissolved canvas',
#  'price_gbp': '£1,400.00',
#  'title': "To The Zenith's Height by Jane Ward",
#  'url': 'https://www.bearspace.co.uk/product-page/to-the-zenith-s-height-by-jane-ward',
#  'width_cm': '120'}, {'height_cm': '75',
#  'media': 'Aluminium, Inkjet Vinyl Print',
#  'price_gbp': '£640.00',
#  'title': 'Somewhat Confusing II by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/somewhat-confusing-ii-by-elise-wootten',
#  'width_cm': '89'}, {'height_cm': '40',
#  'media': 'oil with charcoal, watercolour and pencil on canvas',
#  'price_gbp': '£640.00',
#  'title': 'Morning Came by Dominic Bradnum',
#  'url': 'https://www.bearspace.co.uk/product-page/morning-came-by-dominic-bradnum',
#  'width_cm': '50'}, {'height_cm': '16',
#  'media': '',
#  'price_gbp': '£440.00',
#  'title': 'Kin by Vic Wright',
#  'url': 'https://www.bearspace.co.uk/product-page/kin-by-vic-wright',
#  'width_cm': '14'}, {'height_cm': '42',
#  'media': 'Oil paint, spray paint & gold leaf on board',
#  'price_gbp': '£340.00',
#  'title': 'Another Sunset by Lucy Baker',
#  'url': 'https://www.bearspace.co.uk/product-page/another-sunset-by-lucy-baker',
#  'width_cm': '34'}, {'height_cm': '75',
#  'media': 'Aluminium, Inkjet Vinyl Print',
#  'price_gbp': '£640.00',
#  'title': 'Somewhat Confusing III by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/somewhat-confusing-iii-by-elise-wootten',
#  'width_cm': '88'}, {'height_cm': '90',
#  'media': 'Archival digital print on canvas with dissolved canvas',
#  'price_gbp': '£1,400.00',
#  'title': 'The Ephemeral Isles by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/the-ephemeral-isles-by-jane-ward',
#  'width_cm': '120'}, {'height_cm': '30',
#  'media': 'Oil paint, spray paint & gold leaf on board',
#  'price_gbp': '£340.00',
#  'title': 'OFF ROAD by Lucy Baker',
#  'url': 'https://www.bearspace.co.uk/product-page/off-road-by-lucy-baker',
#  'width_cm': '40'}, {'height_cm': '30',
#  'media': 'Oil paint &\xa0spray paint on board',
#  'price_gbp': '£0.00',
#  'title': 'Hurricane by Lucy Baker',
#  'url': 'https://www.bearspace.co.uk/product-page/hurricane-by-lucy-baker',
#  'width_cm': '40'}, {'height_cm': '110',
#  'media': 'Oil paint, spray paint & gold leaf on board',
#  'price_gbp': '£1,600.00',
#  'title': 'Amazons by Lucy Baker',
#  'url': 'https://www.bearspace.co.uk/product-page/amazons-by-lucy-baker',
#  'width_cm': '130'}, {'height_cm': '110',
#  'media': 'Oil paint, spray paint & gold leaf on board',
#  'price_gbp': '£1,600.00',
#  'title': 'The Hurricane by Lucy Baker',
#  'url': 'https://www.bearspace.co.uk/product-page/the-hurricane-by-lucy-baker',
#  'width_cm': '130'}, {'height_cm': '127',
#  'media': 'Sprayed board Wall based sculpture',
#  'price_gbp': '£3,400.00',
#  'title': 'Candy Flop by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/candy-flop-by-olly-fathers',
#  'width_cm': '53'}, {'height_cm': '40.7',
#  'media': 'Inkjet Print (Hahnemuhle Ultra-Smooth)',
#  'price_gbp': '£340.00',
#  'title': 'Balancing Acts V by Elise Wootten',
#  'url': 'https://www.bearspace.co.uk/product-page/balancing-acts-v-by-elise-wootten',
#  'width_cm': '50.8'}, {'height_cm': '100',
#  'media': 'Spraypaint, board, card, digital print collage',
#  'price_gbp': '£1,940.00',
#  'title': 'Tommy by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/tommy-by-olly-fathers',
#  'width_cm': '70'}, {'height_cm': '38',
#  'media': 'Various wood veneers, various woods, board',
#  'price_gbp': '£1,100.00',
#  'title': 'Constructed Veneer IV by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/constructed-veneer-4-by-olly-fathers',
#  'width_cm': '32'}, {'height_cm': '30',
#  'media': 'Various wood veneers, various woods, board',
#  'price_gbp': '£940.00',
#  'title': 'Constructed Veneer V by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/constructed-veneer-5-by-olly-fathers',
#  'width_cm': '33'}, {'height_cm': '26',
#  'media': 'Various wood veneers, various woods, board',
#  'price_gbp': '£940.00',
#  'title': 'Constructed Veneer VI by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/constructed-veneer-5-by-olly-fathers-1',
#  'width_cm': '24'}, {'height_cm': '29.7',
#  'media': 'Spraypaint, vinyl, card, digital print collage',
#  'price_gbp': '£175.00',
#  'title': 'Collage 3 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/collage-3-by-olly-fathers',
#  'width_cm': '21'}, {'height_cm': '29.7',
#  'media': 'Spraypaint, vinyl, card, digital print collage',
#  'price_gbp': '£175.00',
#  'title': 'Collage 2 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/collage-2-by-olly-fathers',
#  'width_cm': '21'}, {'height_cm': '30',
#  'media': 'Acrylic paint on sprayed board',
#  'price_gbp': '£240.00',
#  'title': 'C6 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/c6-by-olly-fathers',
#  'width_cm': '30'}, {'height_cm': '29.7',
#  'media': 'Spraypaint, vinyl, card, digital print collage',
#  'price_gbp': '£175.00',
#  'title': 'Collage 1 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/collage-1-by-olly-fathers',
#  'width_cm': '21'}, {'height_cm': '34',
#  'media': 'Various wood veneers, various woods, board',
#  'price_gbp': '£940.00',
#  'title': 'Constructed Veneer VII by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/constructed-veneer-vii-by-olly-fathers',
#  'width_cm': '25'}, {'height_cm': '30',
#  'media': 'Acrylic paint on sprayed board',
#  'price_gbp': '£240.00',
#  'title': 'C13 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/c13-by-olly-fathers',
#  'width_cm': '30'}, {'height_cm': '90',
#  'media': '',
#  'price_gbp': '£1,400.00',
#  'title': 'Overland I by Jane Ward',
#  'url': 'https://www.bearspace.co.uk/product-page/overland-i-by-jane-ward',
#  'width_cm': '120'}, {'height_cm': '120',
#  'media': 'Sprayed board Acrylic paint on sprayed board',
#  'price_gbp': '£4,000.00',
#  'title': 'Crossroads by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/crossroads-by-olly-fathers',
#  'width_cm': '120'}, {'height_cm': '30',
#  'media': 'Acrylic paint on sprayed board',
#  'price_gbp': '£240.00',
#  'title': 'P1 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/p1-by-olly-fathers',
#  'width_cm': '30'}, {'height_cm': '30',
#  'media': 'Acrylic paint on sprayed board',
#  'price_gbp': '£240.00',
#  'title': 'P4 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/p4-by-olly-fathers',
#  'width_cm': '30'}, {'height_cm': '30',
#  'media': 'Acrylic paint on sprayed board',
#  'price_gbp': '£240.00',
#  'title': 'P8 by Olly Fathers',
#  'url': 'https://www.bearspace.co.uk/product-page/p8-by-olly-fathers',
#  'width_cm': '30'}]

# %%
import pandas as pd

flights = pd.read_csv("candidateEvalData/flights.csv")
airports = pd.read_csv("candidateEvalData/airports.csv")
weather = pd.read_csv("candidateEvalData/weather.csv")
airlines = pd.read_csv("candidateEvalData/airlines.csv")

# merge the airlines and flights dataframe and rename the 'name' column to 'airline'
df = flights.merge(airlines, on="carrier")
df.rename(columns = {'name':'airline'}, inplace = True)

# filter if string contains "FetBlue"
df = df[df['airline'].str.contains("JetBlue")]

# sort by origin
df = df.sort_values(by=['origin'])

# filter for values of more than 100
df['origin'].value_counts().loc[lambda x : x>100]

"""
INNER JOIN: Retrieves only the rows that have a match in both tables.
LEFT JOIN: Retrieves all rows from the left table and any matching rows from the right table. 
            If there is no match, NULL values are returned for right table's columns.
RIGHT JOIN: Retrieves all rows from the right table and any matching rows from the left table.
FULL OUTER JOIN: Retrieves all rows from both tables, whether or not there is a match in the other table. 
            If there is no match, NULL values are returned for the non-matching columns.

-- Add full airline name to the flights dataframe and show the arr_time, origin, dest and the name of the airline.

ALTER TABLE flights ADD airline CHAR(100)	;

UPDATE flights AS f, airlines as a
SET f.airline = a.name
WHERE f.carrier = a.carrier;

select arr_time, origin, dest, airline from flights;

-- Filter resulting data.frame to include only flights containing the word JetBlue

select * from flights
where airline like '%JetBlue%'

-- Summarise the total number of flights by origin in ascending.

select * from flights
order by origin ASC;

-- Filter resulting data.frame to return only origins with more than 100 flights.
SELECT origin, COUNT(*) FROM flights
group by flights
having COUNT(*) > 100; 

"""
# Out:
# JFK    148
# Name: origin, dtype: int64
